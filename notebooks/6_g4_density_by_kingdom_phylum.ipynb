# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
g4_tool = 'regex'

SPECIES_DATA = "../results/species_data.csv"
G4_PATH = f"../results/{g4_tool}_g4_distribution.csv"

def get_domain(taxa):
    if taxa == 'viral':
        return 'Virus'
    elif taxa == 'bacteria':
        return 'Bacteria'
    elif taxa == 'archaea':
        return 'Archaea'
    else:
        return 'Eukaryota'    

# set color map for domains
color_map = {
    'Virus': '#66c2a5',
    'Bacteria': '#fc8d62',
    'Eukaryota': '#8da0cb',
    'Archaea': '#e78ac3'
}

# %%
# species data
df_species = pd.read_csv(SPECIES_DATA)
df_species = df_species[["Accession", "Genome Size", "GC Percentage", "Taxa", "Kingdom", "Phylum"]]
df_species = df_species.replace('na', np.nan)
df_species["GC Percentage"] = df_species["GC Percentage"].astype(float)
df_species["Genome Size"] = df_species["Genome Size"].astype(float)
df_species["Domain"] = df_species["Taxa"].apply(get_domain)

# g4 data
df_g4 = pd.read_csv(G4_PATH)
df_g4 = df_g4[["accession", "g4_count", "total_g4_length"]]
df_g4 = df_g4.rename(columns={"accession": "Accession"})
df_g4["g4_count"] = df_g4["g4_count"].astype(float)
df_g4["total_g4_length"] = df_g4["total_g4_length"].astype(float)
# merge with species data
df_g4 = pd.merge(df_g4, df_species, on="Accession")
df_g4["G4 Density (per Mb)"] = df_g4["g4_count"] / df_g4["Genome Size"] * 1000000
df_g4["GC Corrected G4 Density (per Mb)"] = df_g4["G4 Density (per Mb)"] / (df_g4["GC Percentage"] / 50)

# filter out metagenomes and other taxa as they are not relevant for domain level analysis
df_g4 = df_g4[df_g4["Taxa"] != "metagenomes"]
df_g4 = df_g4[df_g4["Taxa"] != "other"]

# for viruses, set kingdom as virus
df_g4.loc[df_g4["Taxa"] == "viral", "Kingdom"] = "Virus"

df_g4.head()
# Out:
#          Accession  g4_count  total_g4_length  Genome Size  GC Percentage  \
# 0  GCA_000002515.1      36.0            890.0   10689156.0           38.5
# 1  GCA_000002765.3     837.0          20268.0   23292622.0           19.0
# 2  GCA_000002985.3    2372.0          54608.0  100272607.0           35.0
# 3  GCA_000006605.1     154.0           4017.0    2476822.0           61.0
# 4  GCA_000006645.1      66.0           1652.0    4701745.0           47.5
#
#            Taxa     Kingdom          Phylum     Domain  G4 Density (per Mb)  \
# 0         fungi       Fungi      Ascomycota  Eukaryota             3.367899
# 1      protozoa    Protista     Apicomplexa  Eukaryota            35.934125
# 2  invertebrate    Animalia        Nematoda  Eukaryota            23.655513
# 3      bacteria  Eubacteria  Actinomycetota   Bacteria            62.176450
# 4      bacteria  Eubacteria  Pseudomonadota   Bacteria            14.037341
#
#    GC Corrected G4 Density (per Mb)
# 0                          4.373895
# 1                         94.563488
# 2                         33.793591
# 3                         50.964304
# 4                         14.776149

# %%
# group by kingdom and get mean values
df_k = df_g4.groupby(["Kingdom"]).agg({
    "g4_count": "sum",
    "G4 Density (per Mb)": "mean",
    "GC Corrected G4 Density (per Mb)": "mean",
    "Accession": "count"
    }).reset_index()
df_k.columns = ["Kingdom", "Total no. of G4s", "Average G4 Density (per Mb)", "Average GC Corrected G4 Density (per Mb)", "No. of Species"]

# add new column for G4 occurences per species
df_k["G4 occurrences per species"] = df_k["Total no. of G4s"]/df_k["No. of Species"]
df_k = df_k.sort_values(by="Average G4 Density (per Mb)", ascending=False).reset_index(drop=True)
df_k.head()
# Out:
#     Kingdom  Total no. of G4s  Average G4 Density (per Mb)  \
# 0  Animalia        18828886.0                   132.533108
# 1  Protista          106684.0                   129.443965
# 2   Plantae         3665548.0                   110.945196
# 3     Virus          184611.0                    65.623171
# 4     Fungi          687371.0                    62.642094
#
#    Average GC Corrected G4 Density (per Mb)  No. of Species  \
# 0                                159.687791              78
# 1                                125.906508              27
# 2                                109.238799              68
# 3                                 62.680187           63658
# 4                                 63.117569             351
#
#    G4 occurrences per species
# 0               241395.974359
# 1                 3951.259259
# 2                53905.117647
# 3                    2.900044
# 4                 1958.321937

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))
sns.barplot(x="Average G4 Density (per Mb)", y="Kingdom", data=df_k)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# bar plot for Average G4 Density (per Mb)
sns.set_style("whitegrid")
plt.figure(figsize=(7, 7))
df = pd.DataFrame({
    'Kingdom': df_k['Kingdom'],
    'Average G4 Density (per Mb)': df_k['Average G4 Density (per Mb)'],
    'Average GC Corrected G4 Density (per Mb)': df_k['Average GC Corrected G4 Density (per Mb)']
})
tidy = df.melt(id_vars='Kingdom').rename(columns=str.title)
sns.barplot(x="Value", y="Kingdom", hue='Variable', data=tidy)
plt.title("Average G4 Density (per Mb)")
plt.tight_layout()
plt.ylabel("")
# Out:
# Text(-29.027777777777786, 0.5, '')

# %%
# group by domain and phylum
df_gp = df_g4.groupby(["Domain", "Phylum"]).agg({
	"G4 Density (per Mb)": "mean",
	"GC Corrected G4 Density (per Mb)": "mean",
	"Accession": "count"
}).reset_index()
# get mean, min and max values of averages for phylums in each domain
df_gp = df_gp.groupby("Domain").agg({
	"G4 Density (per Mb)": ["mean", "min", "max", lambda x: x.max()/x.min()],
	"GC Corrected G4 Density (per Mb)": ["mean", "min", "max", lambda x: x.max()/x.min()]
}).reset_index()

df_gp.head()
# Out:
# /var/folders/1r/lnpzqmmd429dz0fv3s3z1hdh0000gr/T/ipykernel_15355/3727202296.py:9: RuntimeWarning: divide by zero encountered in scalar divide
#   "G4 Density (per Mb)": ["mean", "min", "max", lambda x: x.max()/x.min()],
# /var/folders/1r/lnpzqmmd429dz0fv3s3z1hdh0000gr/T/ipykernel_15355/3727202296.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   "GC Corrected G4 Density (per Mb)": ["mean", "min", "max", lambda x: x.max()/x.min()]
#       Domain G4 Density (per Mb)                                     \
#                             mean        min         max  <lambda_0>
# 0    Archaea           19.881777   0.462834   81.914245  176.984106
# 1   Bacteria           47.435984   0.000000  619.750178         inf
# 2  Eukaryota           94.190278   0.000000  518.636141         inf
# 3      Virus           90.850741  10.481360  566.728147   54.070095
#
#   GC Corrected G4 Density (per Mb)
#                               mean        min         max  <lambda_0>
# 0                        19.278007   0.754454   75.846523  100.531643
# 1                        39.656438   0.000000  456.255990         inf
# 2                        99.155651   0.000000  396.551118         inf
# 3                        80.713520  10.240577  457.093441   44.635516

# %%
# group by Phylum and get mean values
df_p = df_g4.groupby(["Phylum"]).agg({
    "Kingdom": "first",
    "g4_count": "sum",
    "G4 Density (per Mb)": "mean",
    "GC Corrected G4 Density (per Mb)": "mean",
    "Accession": "count"
    })
df_p.columns = ["Kingdom", "Total no. of G4s", "Average G4 Density (per Mb)", "Average GC Corrected G4 Density (per Mb)", "No. of Species"]
df_p["G4 Density (per Mb) std error"] = df_g4.groupby(["Phylum"])["G4 Density (per Mb)"].sem()
df_p["G4 occurrences per species"] = df_p["Total no. of G4s"]/df_p["No. of Species"]
df_p = df_p.sort_values(by="Average G4 Density (per Mb)", ascending=False)
df_p.head()
# Out:
#                                Kingdom  Total no. of G4s  \
# Phylum
# Deinococcota                Eubacteria          137640.0
# Peploviricota                    Virus          131520.0
# Chlorophyta                    Plantae          233026.0
# Candidatus Bipolaricaulota  Eubacteria             981.0
# Euglenozoa                    Protista           99599.0
#
#                             Average G4 Density (per Mb)  \
# Phylum
# Deinococcota                                 619.750178
# Peploviricota                                566.728147
# Chlorophyta                                  518.636141
# Candidatus Bipolaricaulota                   333.706325
# Euglenozoa                                   284.058953
#
#                             Average GC Corrected G4 Density (per Mb)  \
# Phylum
# Deinococcota                                              456.255990
# Peploviricota                                             457.093441
# Chlorophyta                                               396.551118
# Candidatus Bipolaricaulota                                246.784702
# Euglenozoa                                                244.358401
#
#                             No. of Species  G4 Density (per Mb) std error  \
# Phylum
# Deinococcota                            86                      44.624193
# Peploviricota                         1414                      14.692764
# Chlorophyta                              9                     172.570520
# Candidatus Bipolaricaulota               2                      76.309849
# Euglenozoa                              11                      33.195109
#
#                             G4 occurrences per species
# Phylum
# Deinococcota                               1600.465116
# Peploviricota                                93.012730
# Chlorophyta                               25891.777778
# Candidatus Bipolaricaulota                  490.500000
# Euglenozoa                                 9054.454545

# %%
# have fixed order for kindoms to ensure consistent coloring in plots
kingdoms = df_p["Kingdom"].unique()
kingdoms = sorted(kingdoms)

sns.set_style("whitegrid")
plt.figure(figsize=(8, 24))
sns.barplot(
    x="Average G4 Density (per Mb)", 
    y="Phylum", 
    hue="Kingdom", 
    hue_order=kingdoms,
    data=df_p
)
# set error bars
plt.errorbar(
    x=df_p["Average G4 Density (per Mb)"], 
    y=df_p.index, 
    xerr=df_p["G4 Density (per Mb) std error"],
    fmt='none',
    c="black"
)

# formatting
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("Average G4 Density (per Mb)", fontsize=12)
plt.ylabel("Phylum", fontsize=12)
plt.legend(loc="lower right", title="", fontsize=16)
plt.tight_layout() 

plt.savefig(f"../plots/g4_density_kingdom_phylum_full_{g4_tool}.png")

# %%
# get top 50 phyla
df_p = df_p[:50]

# have fixed order for kindoms to ensure consistent coloring in plots
kingdoms = df_p["Kingdom"].unique()
kingdoms = sorted(kingdoms)

sns.set_style("whitegrid")
plt.figure(figsize=(7, 14))
sns.barplot(
    x="Average G4 Density (per Mb)", 
    y="Phylum", 
    hue="Kingdom", 
    hue_order=kingdoms,
    data=df_p
)
# set error bars
plt.errorbar(
    x=df_p["Average G4 Density (per Mb)"], 
    y=df_p.index, 
    xerr=df_p["G4 Density (per Mb) std error"],
    fmt='none',
    c="black"
)

# formatting
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel("Average G4 Density (per Mb)", fontsize=16)
plt.ylabel("Phylum", fontsize=16)
plt.legend(loc="lower right", title="", fontsize=16)
plt.tight_layout() 

plt.savefig(f"../plots/g4_density_kingdom_phylum_{g4_tool}.png")
