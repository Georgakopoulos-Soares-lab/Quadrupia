# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import seaborn as sns

# %%
BASE_DIR = "/Users/akshatha/GeorgakopoulosSoaresLab/g4_analysis"
COUNTS = f"{BASE_DIR}/results/counts.txt"
VENN_DIAGRAM = f"{BASE_DIR}/plots/counts_venn.png"

# %%
# get counts
with open (COUNTS, 'r') as f:
    counts = f.read().splitlines()
    counts = [i.split() for i in counts]
data = {i[0][:-1]: int(i[1]) for i in counts}
print(data)
# Out:
# {'G4Hunter': 107350398, 'Regex': 29284758, 'Intersect': 12838580}

# %%
# plot venn diagram
plt.figure(figsize=(6,6))
# specify colors
colors = ['steelblue', 'palevioletred']
# plot venn diagram
v = venn2(subsets = (data['G4Hunter']-data['Intersect'], data['Regex']-data['Intersect'], data['Intersect']), 
      set_labels = None,
      set_colors=colors,
      subset_label_formatter=lambda num: "{:,}".format(num))
plt.tight_layout()
plt.savefig(VENN_DIAGRAM)
